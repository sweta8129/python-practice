# %% [markdown]
# ### Intro

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 5
b = 10
print(a + b)
# Out:
# 15

# %% [markdown]
# Let's play with some code.....
# -> We check in a patient named John Smith.
# -> He is 20 years old.
# -> He is a new patient

# %%
#First we need create a variable called "JOHN SMITH"
# Remember in Python everything is case sensitive
patient_name = "John Smith" #here Python will implictly get to know the value is of String datatype.

#

# %% [markdown]
# Build a patient class using the above values. then try to create another patient record using the same.

# %%
class Patient:
    status = 'New Patient'
    def __init__(self, name, age, status):
        self.name = 'sweta'
        self.age = age
    def change_status_to_old(self):
        self.status = 'Old Patient'
    



patient1 = Patient("John Smith", 20, "Old Patient")
patient2 = Patient("Jane Smith", 21, "Old Patient")


print(patient1.status)
print(patient2.status)

patient2.change_status_to_old()

print(patient2.status)
# Create a patient record
# Out:
# New Patient
# New Patient

# %% [markdown]
# class Patient:
#     def __init__()
