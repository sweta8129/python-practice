# %% [markdown]
# # 18 Data Modeling
# ## Why it matters
# Good modeling makes analytics accurate and performant.
#
# ## Concepts
# - OLTP vs OLAP
# - Star schema and snowflake schema
# - Fact vs dimension table
# - SCD Type 1 and Type 2
# - Defining table grain

# %%
star_schema = {
    "fact_sales": ["order_id", "customer_id", "product_id", "date_id", "amount"],
    "dim_customer": ["customer_id", "customer_name", "region"],
    "dim_product": ["product_id", "product_name", "category"],
    "dim_date": ["date_id", "day", "month", "year"]
}
print(star_schema)
