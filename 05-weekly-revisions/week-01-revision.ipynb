# %% [markdown]
# # Week 1 Revision
#
# Topics: data structures + comprehensions + generators

# %% [markdown]
# ## Mixed challenge set (10 questions)
# 1. Frequency count
# 2. Remove duplicates
# 3. Group transactions by user
# 4. Build dict from tuple list
# 5. Comprehension filtering
# 6. Nested comprehension
# 7. Lazy row generator
# 8. Membership speed rationale
# 9. Convert list to index map
# 10. Deduplicate while preserving order

# %%
# Solve Q1-Q5 here

# %%
# Solve Q6-Q10 here

# %% [markdown]
# ## Timed mini-test (45 min)
# Build a mini pipeline that:
# - Reads a list of transaction dicts
# - Filters invalid rows
# - Aggregates totals per customer
# - Outputs sorted top 3 customers

# %%
# Timed test solution area

# %% [markdown]
# ## Debug challenge
# Fix the bug(s):

# %%
rows = ["1,100", "2,abc", "3,50"]
total = 0
for row in rows:
    user_id, amount = row.split(",")
    total += int(amount)
print(total)

# %% [markdown]
# ## Reflection
# - What was hardest?
# - Which concept still feels weak?
# - What will you revise tomorrow?
