# %% [markdown]
# # Week 2 Revision
#
# Topics: advanced functions + error handling + file I/O

# %% [markdown]
# ## Mixed challenge set
# 1. `*args` aggregator
# 2. `**kwargs` config merge
# 3. Sort with lambda
# 4. map/filter transform
# 5. retry wrapper
# 6. custom exception
# 7. safe parse pipeline
# 8. file write/read
# 9. JSON schema validate
# 10. line-by-line large file read

# %%
# Solve Q1-Q5 here

# %%
# Solve Q6-Q10 here

# %% [markdown]
# ## Timed mini-test (45 min)
# Create a robust ingestion function that:
# - Reads lines from a file
# - Parses CSV-like rows
# - Handles bad rows with try/except
# - Retries transient parsing errors
# - Returns clean records and error stats

# %%
# Timed test solution area

# %% [markdown]
# ## Debug challenge
# Find and fix the issue(s):

# %%
def write_rows(path, rows):
    f = open(path, "w", encoding="utf-8")
    for r in rows:
        f.write(r + "\n")

write_rows("out.txt", ["a", "b"])

# %% [markdown]
# ## Reflection
# - Which pattern will you use in real pipelines?
# - Where did you lose time during debugging?
