# %% [markdown]
# # 16 dbt
# ## Why it matters
# dbt standardizes warehouse transformations with testing and documentation.
#
# ## Concepts
# - Models, staging/intermediate/marts
# - `ref()` dependencies
# - Tests (`not_null`, `unique`)
# - Incremental models

# %%
model_sql = '''
-- models/marts/fct_sales.sql
select
  order_id,
  customer_id,
  amount,
  order_ts
from {{ ref('stg_orders') }}
'''
print(model_sql)
