# %% [markdown]
# # 08 Pandas Basics
# ## Why it matters
# Pandas is the default tool for batch data cleaning and feature preparation.
#
# ## Concepts
# - `Series` and `DataFrame`
# - `loc` vs `iloc`
# - Filtering and groupby aggregation
#
# ## Interview prompts
# 1. When do you use `loc` over `iloc`?
# 2. Why avoid row-by-row loops in Pandas?

# %%
import pandas as pd
df = pd.DataFrame({"team": ["A", "A", "B"], "sales": [100, 200, 150]})
print(df[df["sales"] > 120])
print(df.groupby("team", as_index=False)["sales"].sum())
