# %% [markdown]
# # Topic Title
#
# ## Why this matters for data engineering
# - Bullet 1
# - Bullet 2

# %% [markdown]
# ## Core concept
# Explain concept briefly, then run example.

# %%
# Example
values = [1, 2, 3]
print(sum(values))

# %% [markdown]
# ## Exercises
# 1. Easy
# 2. Medium
# 3. Hard

# %%
# Write your solution here
pass

# %% [markdown]
# ## Self-check
# - [ ] I can explain the concept
# - [ ] I can solve a related problem
# - [ ] I can debug common errors
