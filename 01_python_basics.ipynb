# %% [markdown]
# # 01 Python Basics
#
# ## Why it matters
# Python basics are used in data ingestion scripts, validation logic, and interview coding rounds.
#
# ## Core concepts
# - Variables, data types (`int`, `float`, `str`, `bool`)
# - Type conversion and input handling
# - Control flow (`if`, `for`, `while`)
#
# ## Common pitfalls
# - `input()` returns string: convert before math
# - In prime loops, avoid `break` too early
#
# ## Interview questions
# 1. Difference between `==` and `is`?
# 2. What is truthiness in Python?
#
# ## Hands-on exercises
# - Write a safe age calculator from birth year
# - Print prime numbers from 10 to 50 correctly
#
# ## Further reading
# - https://docs.python.org/3/tutorial/

# %%
birth_year = "1999"
age = 2026 - int(birth_year)
print("Age:", age)

# Correct prime check (fixes early-break logic issue)
for num in range(10, 20):
    is_prime = True
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            break
    if is_prime:
        print(num, "is prime")
