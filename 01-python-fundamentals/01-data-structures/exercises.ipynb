# %% [markdown]
# # Exercises: Data Structures
#
# Solve without opening solutions first.

# %% [markdown]
# ## Easy
# 1. Create a list of 20 numbers and return only even numbers.
# 2. Convert a list with duplicates into unique sorted values.

# %%
# Exercise 1

# %%
# Exercise 2

# %% [markdown]
# ## Medium
# 3. Build a frequency dictionary for words in: "data engineering data python python python".
# 4. Given a list of tuples `(user_id, amount)`, compute total amount per user.

# %%
# Exercise 3

# %%
# Exercise 4

# %% [markdown]
# ## Hard
# 5. Given transaction dicts, create a dict keyed by `customer_id` with list of transaction IDs.

# %%
# Exercise 5
transactions = [
    {"id": 1, "customer_id": "C1"},
    {"id": 2, "customer_id": "C2"},
    {"id": 3, "customer_id": "C1"},
]

# %% [markdown]
# ## Self-check
# - [ ] I solved all exercises
# - [ ] I can explain time complexity basics
