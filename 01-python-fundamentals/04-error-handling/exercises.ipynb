# %% [markdown]
# # Exercises: Error Handling

# %% [markdown]
# 1. Handle invalid integer input and return fallback value -1.

# %%
# Exercise 1

# %% [markdown]
# 2. Write custom exception `SchemaError` and raise it when required keys are missing.

# %%
# Exercise 2

# %% [markdown]
# 3. Build a retry wrapper around a flaky function with max retries.

# %%
# Exercise 3
