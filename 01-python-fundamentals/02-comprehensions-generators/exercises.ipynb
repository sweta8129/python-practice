# %% [markdown]
# # Exercises: Comprehensions and Generators

# %% [markdown]
# 1. Build a list of squares from 1 to 30 using list comprehension.

# %%
# Exercise 1

# %% [markdown]
# 2. Build a dict mapping each word to its length from a sentence.

# %%
# Exercise 2
sentence = "stream large data efficiently"

# %% [markdown]
# 3. Write a generator that yields only even numbers from an input iterable.

# %%
# Exercise 3

# %% [markdown]
# 4. Hard: Simulate reading 1M rows lazily and count rows without storing all rows.

# %%
# Exercise 4
