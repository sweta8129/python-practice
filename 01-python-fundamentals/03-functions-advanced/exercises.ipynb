# %% [markdown]
# # Exercises: Advanced Functions

# %% [markdown]
# 1. Write a function `multiply_all(*nums)` that returns the product of all inputs.

# %%
# Exercise 1

# %% [markdown]
# 2. Sort a list of dicts by timestamp string field using `key=`.

# %%
# Exercise 2

# %% [markdown]
# 3. Use `filter` to keep valid records where `amount > 0`.

# %%
# Exercise 3

# %% [markdown]
# 4. Create a decorator that measures and prints execution time.

# %%
# Exercise 4
