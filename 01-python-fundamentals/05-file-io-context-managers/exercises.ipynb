# %% [markdown]
# # Exercises: File I/O and Context Managers

# %% [markdown]
# 1. Write 100 lines to a file `numbers.txt` using `with`.

# %%
# Exercise 1

# %% [markdown]
# 2. Read `numbers.txt` and compute sum of values.

# %%
# Exercise 2

# %% [markdown]
# 3. Save list of records as JSON and read it back.

# %%
# Exercise 3

# %% [markdown]
# 4. Hard: create generator to stream a file and return only rows containing a keyword.

# %%
# Exercise 4
