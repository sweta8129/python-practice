# %% [markdown]
# # Strings (legacy notebook)
#
# This content is now organized in `03_strings_and_regex.ipynb`.
#
# Open that notebook for the full structured module with concepts, pitfalls, interview questions, and exercises.

# %%
"""WHY IS THIS IMPORTANT??"""
#Internally STRINGS ARE STORED AS ARRAYS OF CHARACTERS and included in single strings.
# Out:
# 'WHY IS THIS IMPORTANT??'

# %% [markdown]
# ACCESSING THE

# %%
def summation(arr):
    """ This is doc string """
    total = 0
    for i in arr:
        total += i
    return total

print(summation([1,2,3,4,5]))
