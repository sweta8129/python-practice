# %% [markdown]
# # 19 System Design for Data Engineering
# ## Why it matters
# DE interviews test architecture decisions, trade-offs, and reliability patterns.
#
# ## Concepts
# - Batch vs streaming
# - Data lake vs warehouse vs lakehouse
# - CDC and schema evolution
# - Partitioning and backfill strategy
#
# ## Case studies
# 1. Clickstream pipeline design
# 2. Daily business metrics warehouse design

# %%
design_checklist = [
    "Data source characteristics",
    "SLA and freshness",
    "Expected volume and partition key",
    "Failure handling and retries",
    "Cost and observability"
]
print(design_checklist)
