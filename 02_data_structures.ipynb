# %% [markdown]
# # 02 Data Structures
#
# ## Why it matters
# DE work uses lists/dicts/sets in parsing APIs, grouping records, and deduping keys.
#
# ## Core concepts
# - Lists, tuples, sets, dicts
# - Comprehensions
# - `collections.Counter`, `defaultdict`, `namedtuple`
#
# ## Common pitfalls
# - Do not name variables `dict`, `list`, `set`
# - Understand mutability
#
# ## Interview questions
# 1. List vs tuple differences?
# 2. When to use a set over list?
#
# ## Exercises
# - Count words in a paragraph
# - Deduplicate IDs while preserving order

# %%
from collections import Counter, defaultdict

words = ["etl", "sql", "etl", "python", "sql", "etl"]
counts = Counter(words)
print(counts)

groups = defaultdict(list)
records = [("A", 10), ("B", 20), ("A", 40)]
for key, value in records:
    groups[key].append(value)
print(dict(groups))
